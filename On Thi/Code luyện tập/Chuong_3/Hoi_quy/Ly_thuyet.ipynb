# %% [markdown]
# Phân loại:
# Dự đoán nhãn/lớp
# Ví dụ: ác tính/lành tính
# Đánh giá: Accuracy, F1-score, Recall, Confusion Matrix
#
# Hồi quy:
# Dự đoán số liên tục
# Ví dụ: giá nhà, chi phí, điểm số
# Đánh giá: MAE, MSE, RMSE, R²
# Vẽ: Actual vs PredictedCác mô hình thường dùng cho **bài toán hồi quy** là các mô hình có nhiệm vụ dự đoán **giá trị số liên tục**, ví dụ: giá nhà, chi phí y tế, nhiệt độ, doanh thu, điểm số.
#
# Trong **đề cương của bạn**, phần hồi quy cần ôn 4 mô hình chính: **Linear Regression, Decision Tree Regressor, Gradient Boosting Regressor, KNN Regressor**.
# Đúng rồi bạn. Mình **chốt riêng cho bài toán hồi quy** theo đúng đề cương của bạn nhé. Trong đề cương, hồi quy cần ôn chính: **Linear Regression, Decision Tree Regressor, Gradient Boosting Regressor, KNN Regressor**, chỉ số chính là **MSE** và **R-squared**.
#
# # 1. Mô hình hồi quy cần nhớ
#
# | Mô hình                     | Cách import thư viện                                     | Cách gọi mô hình              | Ghi nhớ nhanh                     |
# | --------------------------- | -------------------------------------------------------- | ----------------------------- | --------------------------------- |
# | Linear Regression           | `from sklearn.linear_model import LinearRegression`      | `LinearRegression()`          | Hồi quy tuyến tính, dễ hiểu       |
# | Decision Tree Regressor     | `from sklearn.tree import DecisionTreeRegressor`         | `DecisionTreeRegressor()`     | Cây quyết định cho hồi quy        |
# | Gradient Boosting Regressor | `from sklearn.ensemble import GradientBoostingRegressor` | `GradientBoostingRegressor()` | Mô hình mạnh, học từ lỗi          |
# | KNN Regressor               | `from sklearn.neighbors import KNeighborsRegressor`      | `KNeighborsRegressor()`       | Dự đoán dựa vào các điểm gần nhất |
#
# ## Mẫu import đầy đủ
#
# ```python
# from sklearn.linear_model import LinearRegression
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import GradientBoostingRegressor
# from sklearn.neighbors import KNeighborsRegressor
# ```
#
# ## Mẫu gọi mô hình
#
# ```python
# mo_hinh_1 = LinearRegression()
#
# mo_hinh_2 = DecisionTreeRegressor(
#     max_depth=5,
#     random_state=42
# )
#
# mo_hinh_3 = GradientBoostingRegressor(
#     n_estimators=50,
#     random_state=42
# )
#
# mo_hinh_4 = KNeighborsRegressor(
#     n_neighbors=5
# )
# ```
#
# # 2. Chỉ số đánh giá hồi quy cần nhớ
#
# | Chỉ số | Cách import thư viện                              | Cách gọi                               | Tác dụng                             | Nhận xét            |
# | ------ | ------------------------------------------------- | -------------------------------------- | ------------------------------------ | ------------------- |
# | MAE    | `from sklearn.metrics import mean_absolute_error` | `mean_absolute_error(y_test, du_doan)` | Đo sai số tuyệt đối trung bình       | Càng nhỏ càng tốt   |
# | MSE    | `from sklearn.metrics import mean_squared_error`  | `mean_squared_error(y_test, du_doan)`  | Đo trung bình bình phương sai số     | Càng nhỏ càng tốt   |
# | RMSE   | Dùng `numpy.sqrt()` kết hợp MSE                   | `np.sqrt(mse)`                         | Căn bậc hai của MSE, dễ hiểu hơn MSE | Càng nhỏ càng tốt   |
# | R²     | `from sklearn.metrics import r2_score`            | `r2_score(y_test, du_doan)`            | Đo mức độ mô hình giải thích dữ liệu | Càng gần 1 càng tốt |
#
# ## Mẫu import chỉ số
#
# ```python
# import numpy as np
#
# from sklearn.metrics import mean_absolute_error
# from sklearn.metrics import mean_squared_error
# from sklearn.metrics import r2_score
# ```
#
# ## Mẫu tính chỉ số
#
# ```python
# mae = mean_absolute_error(y_test, du_doan)
# mse = mean_squared_error(y_test, du_doan)
# rmse = np.sqrt(mse)
# r2 = r2_score(y_test, du_doan)
#
# print("MAE:", mae)
# print("MSE:", mse)
# print("RMSE:", rmse)
# print("R2:", r2)
# ```
